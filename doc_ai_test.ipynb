# %%
import os
from concurrent.futures import ThreadPoolExecutor

import pandas as pd
import re

from typing import Optional

import requests
from google.api_core.client_options import ClientOptions
from google.api_core.exceptions import InternalServerError
from google.api_core.exceptions import RetryError
from google.cloud import documentai
from google.cloud import storage

from datetime import datetime
from dotenv import load_dotenv
from google.cloud import documentai
from google.cloud.documentai_toolbox import gcs_utilities

# %%
cred_file = "odjfs-extraction-a3f45668cd7e.json"

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = cred_file

# %%
load_dotenv()
DOC_PROCESSOR_KEY = os.getenv('DOC_PROCESSOR_KEY')
DOC_PROCESSOR_ID = os.getenv('DOC_PROCESSOR_ID')
PROJECT_ID = os.getenv('PROJECT_ID')

# %%
def create_gcs_bucket(bucket_name, delete=False):
    """Deletes the bucket if it exists, then creates a new bucket in Google Cloud Storage."""
    storage_client = storage.Client()

    # Check if the bucket already exists
    bucket = storage_client.lookup_bucket(bucket_name)
    if bucket and delete:
        print(f"Bucket {bucket_name} already exists. Deleting it...")
        bucket.delete(force=True)
        print(f"Bucket {bucket_name} deleted.")

        # create a new bucket
        new_bucket = storage_client.create_bucket(bucket_name)
        print(f"Bucket {new_bucket.name} created.")

    return storage_client.bucket(bucket_name)

# %%
bucket = create_gcs_bucket("odjfs-test")

# %%
import fitz
import io

def download_and_upload_pdf(bucket, blob_name, pdf_url, page_count=1):
    """
    Download a PDF from a URL and upload it to GCS.
    
    :param bucket: GCS bucket object
    :param blob_name: name of the PDF file (e.g., the PDF's ID)
    :param pdf_url: URL of the PDF file
    :param page_count: number of pages to download
    
    """
    try:
        response = requests.get(pdf_url)
        response.raise_for_status()
        pdf_content = response.content

        # retrieve the first page_count pages 
        input_pdf = fitz.open(stream=pdf_content, filetype='pdf')
        output_pdf = fitz.open()
        output_pdf.insert_pdf(input_pdf, from_page=0, to_page=page_count - 1)

        # convert to temporary "file" for upload 
        pdf_buffer = io.BytesIO()
        output_pdf.save(pdf_buffer, incremental=False)
        pdf_buffer.seek(0)

        # upload to GCS
        blob = bucket.blob(blob_name)
        blob.upload_from_file(pdf_buffer, content_type='application/pdf')
        print(f"Uploaded {blob_name} to GCS.")
    except Exception as e:
        print(f"Failed to process {pdf_url}: {e}")

# %%
pdf_links = pd.read_csv("test/pdf_links_test.csv", index_col=0)
pdf_links.head()
# Out:
#                                                  program_name  \
# program_id
# 2190020840  "BECOMING ME" SOCIAL AND EMOTIONAL LEARNING EN...
# 2190020063                              1ST CHOICE CHILD CARE
# 300864                           1ST FRIENDS LEARNING ACADEMY
# 2190019999                                    3MB AFTERSCHOOL
# 201048                             3T LEARNING ACADEMY LLC 11
#
#                                                           pdf  \
# program_id
# 2190020840  https://childcaresearch.ohio.gov//pdf/00219002...
# 2190020063  https://childcaresearch.ohio.gov//pdf/00219002...
# 300864      https://childcaresearch.ohio.gov//pdf/00000030...
# 2190019999  https://childcaresearch.ohio.gov//pdf/00219001...
# 201048      https://childcaresearch.ohio.gov//pdf/00000020...
#
#                            Address        City    Zip
# program_id
# 2190020840           2627 PARK AVE  CINCINNATI  45206
# 2190020063      4303 CLEVELAND AVE    COLUMBUS  43224
# 300864               1930 PEARL RD   BRUNSWICK  44212
# 2190019999  18316 ST. CLAIR AVENUE   CLEVELAND  44110
# 201048           7523 READING ROAD  CINCINNATI  45237

# %%
len(pd.read_csv("data/pdf_links_final.csv",index_col=0)['pdf'])
# Out:
# 3746

# %%
# from main import upload_files_to_gcs
# upload_files_to_gcs(
#     bucket, 
#     pd.read_csv("data/pdf_links_final.csv", index_col=0)['pdf'].iloc[0:50],
#     batch_size=10,
#     num_workers=5,
#     num_pages=2
# )
# Out:
# Uploaded input/107193.pdf to GCS.
# Uploaded input/2180016960.pdf to GCS.
# Uploaded input/2190020297.pdf to GCS.
# Uploaded input/200644.pdf to GCS.
# Uploaded input/2190020063.pdf to GCS.
# Uploaded input/207607.pdf to GCS.
# Uploaded input/2220026701.pdf to GCS.
# Uploaded input/2180017710.pdf to GCS.
# Uploaded input/300864.pdf to GCS.
# Uploaded input/107064.pdf to GCS.
# Uploaded input/300001.pdf to GCS.
# Uploaded input/400468.pdf to GCS.
# Uploaded input/2200022316.pdf to GCS.
# Uploaded input/2210025267.pdf to GCS.
# Uploaded input/401180.pdf to GCS.
# Uploaded input/2190019999.pdf to GCS.
# Uploaded input/306543.pdf to GCS.
# Uploaded input/2210024741.pdf to GCS.
# Uploaded input/2180018327.pdf to GCS.
# Uploaded input/2220026936.pdf to GCS.
# Uploaded input/2190019520.pdf to GCS.
# Uploaded input/201048.pdf to GCS.
# Uploaded input/400610.pdf to GCS.
# Uploaded input/307578.pdf to GCS.
# Uploaded input/104554.pdf to GCS.
# Uploaded input/2210025027.pdf to GCS.
# Uploaded input/207853.pdf to GCS.
# Uploaded input/2220025784.pdf to GCS.
# Uploaded input/500191.pdf to GCS.
# Uploaded input/2210025291.pdf to GCS.
# Uploaded input/200979.pdf to GCS.
# Uploaded input/2170014790.pdf to GCS.
# Uploaded input/400839.pdf to GCS.
# Uploaded input/407193.pdf to GCS.
# Uploaded input/203941.pdf to GCS.
# Uploaded input/500276.pdf to GCS.
# Uploaded input/400965.pdf to GCS.
# Uploaded input/205547.pdf to GCS.
# Uploaded input/2200022786.pdf to GCS.
# Uploaded input/307339.pdf to GCS.
# Uploaded input/2200022034.pdf to GCS.
# Uploaded input/2170012482.pdf to GCS.
# Uploaded input/2180016806.pdf to GCS.
# Failed to process https://childcaresearch.ohio.gov//pdf/002180019164_2024-08-07_ANNUAL.pdf: 404 Client Error: Not Found for url: https://childcaresearch.ohio.gov//pdf/002180019164_2024-08-07_ANNUAL.pdf
# Uploaded input/401176.pdf to GCS.
# Uploaded input/2230027669.pdf to GCS.
# Uploaded input/2170012594.pdf to GCS.
# Uploaded input/100361.pdf to GCS.
# Uploaded input/2230027870.pdf to GCS.
# All batches processed.

# %%
test_link = pdf_links.iloc[0]['pdf']
test_link
# Out:
# 'https://childcaresearch.ohio.gov//pdf/002190020840_2023-10-25_ANNUAL.pdf'

# %%
# download_and_upload_pdf(bucket, "input/002190020840.pdf", test_link)
# Out:
# Uploaded input/002190020840.pdf to GCS.

# %%
def extract_from_pdfs(
        gcs_bucket_name: str,
        gcs_prefix: str,
        batch_size: int = 50,
        location='us',
        field_mask: Optional[str] = None,
        timeout: int = 400,
        verbose=True
):

    opts = ClientOptions(api_endpoint=f"{location}-documentai.googleapis.com")

    client = documentai.DocumentProcessorServiceClient(client_options=opts)
    
    # Cloud Storage URI for the Output Directory
    gcs_output_config = documentai.DocumentOutputConfig.GcsOutputConfig(
        gcs_uri="gs://odjfs-test/output/", field_mask=field_mask
    )

    # Where to write results
    output_config = documentai.DocumentOutputConfig(gcs_output_config=gcs_output_config)

    batches = gcs_utilities.create_batches(
        gcs_bucket_name=gcs_bucket_name, 
        gcs_prefix=gcs_prefix, 
        batch_size=batch_size
    )

    proc_name = client.processor_path(PROJECT_ID, location="us", processor=DOC_PROCESSOR_ID)

    if verbose:
        print(f"{len(batches)} batch(es) created.")
    
    processed_docs = [] 
    
    for i, batch in enumerate(batches):
        # print(f"{len(batch.gcs_documents.documents)} files in batch.")
        # print(batch.gcs_documents.documents)

        request = documentai.BatchProcessRequest(
            name=proc_name, 
            input_documents=batch,
            document_output_config=output_config
        )
        
        processed_docs.append(process_batch(client, request, timeout, verbose)) 
        
    return pd.concat(processed_docs)

# %%
def process_batch(client: documentai.DocumentProcessorServiceClient, request, timeout, verbose=False):
    
    operation = client.batch_process_documents(request)
    
    # wait until the batch process is complete
    try:
        if verbose:
            print(f"Waiting for operation {operation.operation.name} to complete...")
        operation.result(timeout=timeout)
    # Catch exception when operation doesn't finish before timeout
    except (RetryError, InternalServerError) as e:
        print(e.message)
            
    # NOTE: Can also use callbacks for asynchronous processing
    #
    # def my_callback(future):
    #   result = future.result()
    #
    # operation.add_done_callback(my_callback)

    # After the operation is complete,
    # get output document information from operation metadata
    metadata = documentai.BatchProcessMetadata(operation.metadata)

    if metadata.state != documentai.BatchProcessMetadata.State.SUCCEEDED:
        raise ValueError(f"Batch Process Failed: {metadata.state_message}")

    storage_client = storage.Client()
    
    documents = []

    if verbose:
        print("Output files:")
    # One process per Input Document
    for process in list(metadata.individual_process_statuses):
        # output_gcs_destination format: gs://BUCKET/PREFIX/OPERATION_NUMBER/INPUT_FILE_NUMBER/
        # The Cloud Storage API requires the bucket name and URI prefix separately
        matches = re.match(r"gs://(.*?)/(.*)", process.output_gcs_destination)
        if not matches:
            print(
                "Could not parse output GCS destination:",
                process.output_gcs_destination,
            )
            continue

        output_bucket, output_prefix = matches.groups()

        # Get List of Document Objects from the Output Bucket
        output_blobs = storage_client.list_blobs(output_bucket, prefix=output_prefix)

        # Document AI may output multiple JSON files per source file
        current_doc_fields = {}
        doc_ID = None
        for blob in output_blobs:
            # Document AI should only output JSON files to GCS
            if blob.content_type != "application/json":
                print(
                    f"Skipping non-supported file: {blob.name} - Mimetype: {blob.content_type}"
                )
                continue
                
            if doc_ID is None:
                doc_ID = blob.name.split("/")[-1].split(".")[0].split("-")[0]

            # Download JSON File as bytes object and convert to Document Object
            if verbose:
                print(f"Fetching {blob.name}")
            document = documentai.Document.from_json(
                blob.download_as_bytes(), ignore_unknown_fields=True
            )
            
            fields = get_fields(document)
            current_doc_fields.update(fields)
            
        documents.append(pd.DataFrame(current_doc_fields, index=[doc_ID]))

    return pd.concat(documents)

# %%
processed = extract_from_pdfs(
        gcs_bucket_name="odjfs-test",
        gcs_prefix="test/quarantine",
        batch_size=1,
        field_mask="entities"
)
processed
# Out:
# 1 batch(es) created.
# Waiting for operation projects/406890213804/locations/us/operations/7742598543856842495 to complete...
# Output files:
# Fetching output/7742598543856842495/0/200979-0.json
#        Begin-Time  End-Time
# 200979    9:00 AM  11:30 AM

# %%
processed
# Out:
#           End-Time Moderate-Risk                              Program-Name  \
# 100361-0   1:58 PM             0                     A 2 Z PRESCHOOL, INC.
# 104554-0   6:14 PM             0   A PLACE TO LEARN AND GROW\nINCORPORATED
# 107064-0   3:00 PM             0                  A PLACE FOR EVERYONE LLC
# 107193-0   3:45 PM             1  A BEAUTIFUL CHILD'S PRESCHOOL &\nDAYCARE
# 200644-0  11:45 AM             0               A GREAT START PRESCHOOL INC
# 200979-0  11:30 AM           NaN                                       NaN
#
#          Rules-Verified-Non-Compliance Serious-Risk Full-Time-Infant  \
# 100361-0                             2            0               11
# 104554-0                             7            0                9
# 107064-0                            12            0                5
# 107193-0                             5            0                1
# 200644-0                             0            0                0
# 200979-0                           NaN          NaN              NaN
#
#          Older-Toddler-Full-Time Older-Toddler-Part-Time Older-Toddler-Total  \
# 100361-0                      10                       0                  10
# 104554-0                      14                       0                  14
# 107064-0                       3                       0                   3
# 107193-0                       0                       0                   0
# 200644-0                       0                      30                  30
# 200979-0                     NaN                     NaN                 NaN
#
#          Part-Time-Infant  ... Inspection-Notice  \
# 100361-0                0  ...       Unannounced
# 104554-0                0  ...       Unannounced
# 107064-0                0  ...       Unannounced
# 107193-0                0  ...       Unannounced
# 200644-0                0  ...       Unannounced
# 200979-0              NaN  ...               NaN
#
#          Fire-Inspection-Approval-Date Inspection-Scope Maximum-Under-2  \
# 100361-0                    03/19/2024             Full              26
# 104554-0                    12/29/2022             Full              40
# 107064-0                    12/21/2023             Full               ½
# 107193-0                    11/23/2016             Full               0
# 200644-0                    08/28/2024             Full               ½
# 200979-0                           NaN              NaN             NaN
#
#          Inspection-Date Food-Service-Risk-Level           Reviewer  \
# 100361-0      12/10/2024                Level II      JENNIFER COPE
# 104554-0      10/11/2023               Level III      MICHELE FAKAN
# 107064-0      12/10/2024                  Exempt  SARAH HEIL-HINTON
# 107193-0      12/05/2024               Level III         BETH RAGLE
# 200644-0      11/21/2024                  Exempt       BRENDA MEYER
# 200979-0             NaN                     NaN                NaN
#
#          Begin-Time Rules-Verified Building-Approval-Date
# 100361-0   10:20 AM             58                    NaN
# 104554-0   11:35 AM             58             08/15/2001
# 107064-0   11:10 AM             58             10/02/2009
# 107193-0    9:45 AM             58             10/05/2015
# 200644-0   10:00 AM             58             07/15/2024
# 200979-0    9:00 AM            NaN                    NaN
#
# [6 rows x 37 columns]

# %%
def norm_text(text: str): 
    """ Removes spaces and newline characters. """ 
    return (
        text
        .strip()
        .replace("\n", " ")
        .lower()
    )

# %%
processed[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 processed[1]
#
# IndexError: list index out of range

# %%
document = processed[0]

# %%
def get_fields(document):
    fields = {}
    
    for ent in document.entities:

        # process the table (listed as grouped fields/entities 
        if ent.properties:
            fields.update({prop.type_: prop.mention_text for prop in ent.properties}) 
        else:
            fields[ent.type_] = ent.mention_text
            
    return fields

# get_fields(processed)

# %%
document.entities[1].properties
# Out:
# []

# %%
document.entities[0].properties
# Out:
# [text_anchor {
#   text_segments {
#     start_index: 1442
#     end_index: 1444
#   }
# }
# type_: "Full-Time-Infant"
# mention_text: "11"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.452218443
#         y: 0.738901079
#       }
#       normalized_vertices {
#         x: 0.473265082
#         y: 0.738901079
#       }
#       normalized_vertices {
#         x: 0.473265082
#         y: 0.747252762
#       }
#       normalized_vertices {
#         x: 0.452218443
#         y: 0.747252762
#       }
#     }
#   }
# }
# id: "1"
# normalized_value {
#   text: "11"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1519
#     end_index: 1521
#   }
# }
# type_: "Older-Toddler-Full-Time"
# mention_text: "10"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.452218443
#         y: 0.792967
#       }
#       normalized_vertices {
#         x: 0.473833889
#         y: 0.792967
#       }
#       normalized_vertices {
#         x: 0.473833889
#         y: 0.800879121
#       }
#       normalized_vertices {
#         x: 0.452218443
#         y: 0.800879121
#       }
#     }
#   }
# }
# id: "2"
# normalized_value {
#   text: "10"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1522
#     end_index: 1523
#   }
# }
# type_: "Older-Toddler-Part-Time"
# mention_text: "0"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.578498304
#         y: 0.792527497
#       }
#       normalized_vertices {
#         x: 0.592719
#         y: 0.792527497
#       }
#       normalized_vertices {
#         x: 0.592719
#         y: 0.800439537
#       }
#       normalized_vertices {
#         x: 0.578498304
#         y: 0.800439537
#       }
#     }
#   }
# }
# id: "3"
# normalized_value {
#   text: "0"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1524
#     end_index: 1526
#   }
# }
# type_: "Older-Toddler-Total"
# mention_text: "10"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.791808903
#         y: 0.792967
#       }
#       normalized_vertices {
#         x: 0.812855542
#         y: 0.792967
#       }
#       normalized_vertices {
#         x: 0.812855542
#         y: 0.800879121
#       }
#       normalized_vertices {
#         x: 0.791808903
#         y: 0.800879121
#       }
#     }
#   }
# }
# id: "4"
# normalized_value {
#   text: "10"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1445
#     end_index: 1446
#   }
# }
# type_: "Part-Time-Infant"
# mention_text: "0"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.579636
#         y: 0.739340663
#       }
#       normalized_vertices {
#         x: 0.591012537
#         y: 0.739340663
#       }
#       normalized_vertices {
#         x: 0.591012537
#         y: 0.747252762
#       }
#       normalized_vertices {
#         x: 0.579636
#         y: 0.747252762
#       }
#     }
#   }
# }
# id: "5"
# normalized_value {
#   text: "0"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1537
#     end_index: 1539
#   }
# }
# type_: "Preschool-Full-Time"
# mention_text: "44"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.451080769
#         y: 0.809230745
#       }
#       normalized_vertices {
#         x: 0.4755404
#         y: 0.809230745
#       }
#       normalized_vertices {
#         x: 0.4755404
#         y: 0.818461537
#       }
#       normalized_vertices {
#         x: 0.451080769
#         y: 0.818461537
#       }
#     }
#   }
# }
# id: "6"
# normalized_value {
#   text: "44"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1540
#     end_index: 1542
#   }
# }
# type_: "Preschool-Part-Time"
# mention_text: "11"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.574516475
#         y: 0.809670329
#       }
#       normalized_vertices {
#         x: 0.596132
#         y: 0.809670329
#       }
#       normalized_vertices {
#         x: 0.596132
#         y: 0.818021953
#       }
#       normalized_vertices {
#         x: 0.574516475
#         y: 0.818021953
#       }
#     }
#   }
# }
# id: "7"
# normalized_value {
#   text: "11"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1543
#     end_index: 1545
#   }
# }
# type_: "Preschool-Total"
# mention_text: "55"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.79237771
#         y: 0.810109913
#       }
#       normalized_vertices {
#         x: 0.813424349
#         y: 0.810109913
#       }
#       normalized_vertices {
#         x: 0.813424349
#         y: 0.818461537
#       }
#       normalized_vertices {
#         x: 0.79237771
#         y: 0.818461537
#       }
#     }
#   }
# }
# id: "8"
# normalized_value {
#   text: "55"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1557
#     end_index: 1558
#   }
# }
# type_: "School-Age-Full-Time"
# mention_text: "0"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.457337886
#         y: 0.82769233
#       }
#       normalized_vertices {
#         x: 0.469283283
#         y: 0.82769233
#       }
#       normalized_vertices {
#         x: 0.469283283
#         y: 0.83560437
#       }
#       normalized_vertices {
#         x: 0.457337886
#         y: 0.83560437
#       }
#     }
#   }
# }
# id: "9"
# normalized_value {
#   text: "0"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1559
#     end_index: 1560
#   }
# }
# type_: "School-Age-Part-Time"
# mention_text: "0"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.579067111
#         y: 0.827252746
#       }
#       normalized_vertices {
#         x: 0.593287826
#         y: 0.827252746
#       }
#       normalized_vertices {
#         x: 0.593287826
#         y: 0.83560437
#       }
#       normalized_vertices {
#         x: 0.579067111
#         y: 0.83560437
#       }
#     }
#   }
# }
# id: "10"
# normalized_value {
#   text: "0"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1561
#     end_index: 1562
#   }
# }
# type_: "School-Age-Total"
# mention_text: "0"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.796928346
#         y: 0.82769233
#       }
#       normalized_vertices {
#         x: 0.808304906
#         y: 0.82769233
#       }
#       normalized_vertices {
#         x: 0.808304906
#         y: 0.836043954
#       }
#       normalized_vertices {
#         x: 0.796928346
#         y: 0.836043954
#       }
#     }
#   }
# }
# id: "11"
# normalized_value {
#   text: "0"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1589
#     end_index: 1592
#   }
# }
# type_: "Total-Capacity-or-Enrollment"
# mention_text: "180"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.286120594
#         y: 0.845714271
#       }
#       normalized_vertices {
#         x: 0.317406148
#         y: 0.845714271
#       }
#       normalized_vertices {
#         x: 0.317406148
#         y: 0.853186786
#       }
#       normalized_vertices {
#         x: 0.286120594
#         y: 0.853186786
#       }
#     }
#   }
# }
# id: "12"
# normalized_value {
#   text: "180"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1593
#     end_index: 1595
#   }
# }
# type_: "Total-Full-Time"
# mention_text: "54"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.452218443
#         y: 0.845274746
#       }
#       normalized_vertices {
#         x: 0.474971563
#         y: 0.845274746
#       }
#       normalized_vertices {
#         x: 0.474971563
#         y: 0.85362637
#       }
#       normalized_vertices {
#         x: 0.452218443
#         y: 0.85362637
#       }
#     }
#   }
# }
# id: "13"
# normalized_value {
#   text: "54"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1447
#     end_index: 1449
#   }
# }
# type_: "Total-Infant"
# mention_text: "11"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.791808903
#         y: 0.739780247
#       }
#       normalized_vertices {
#         x: 0.813424349
#         y: 0.739780247
#       }
#       normalized_vertices {
#         x: 0.813424349
#         y: 0.747692287
#       }
#       normalized_vertices {
#         x: 0.791808903
#         y: 0.747692287
#       }
#     }
#   }
# }
# id: "14"
# normalized_value {
#   text: "11"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1596
#     end_index: 1598
#   }
# }
# type_: "Total-Part-Time"
# mention_text: "11"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.574516475
#         y: 0.845274746
#       }
#       normalized_vertices {
#         x: 0.594994307
#         y: 0.845274746
#       }
#       normalized_vertices {
#         x: 0.594994307
#         y: 0.85362637
#       }
#       normalized_vertices {
#         x: 0.574516475
#         y: 0.85362637
#       }
#     }
#   }
# }
# id: "15"
# normalized_value {
#   text: "11"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1494
#     end_index: 1496
#   }
# }
# type_: "Total-Under-2"
# mention_text: "54"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.28668943
#         y: 0.77494508
#       }
#       normalized_vertices {
#         x: 0.308304906
#         y: 0.77494508
#       }
#       normalized_vertices {
#         x: 0.308304906
#         y: 0.783296704
#       }
#       normalized_vertices {
#         x: 0.28668943
#         y: 0.783296704
#       }
#     }
#   }
# }
# id: "16"
# normalized_value {
#   text: "54"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1464
#     end_index: 1466
#   }
# }
# type_: "Young-Toddler-Full-Time"
# mention_text: "15"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.452218443
#         y: 0.756923079
#       }
#       normalized_vertices {
#         x: 0.473265082
#         y: 0.756923079
#       }
#       normalized_vertices {
#         x: 0.473265082
#         y: 0.765274704
#       }
#       normalized_vertices {
#         x: 0.452218443
#         y: 0.765274704
#       }
#     }
#   }
# }
# id: "17"
# normalized_value {
#   text: "15"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1467
#     end_index: 1468
#   }
# }
# type_: "Young-Toddler-Part-Time"
# mention_text: "0"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.579636
#         y: 0.757362664
#       }
#       normalized_vertices {
#         x: 0.591012537
#         y: 0.757362664
#       }
#       normalized_vertices {
#         x: 0.591012537
#         y: 0.765274704
#       }
#       normalized_vertices {
#         x: 0.579636
#         y: 0.765274704
#       }
#     }
#   }
# }
# id: "18"
# normalized_value {
#   text: "0"
# }
# , text_anchor {
#   text_segments {
#     start_index: 1469
#     end_index: 1471
#   }
# }
# type_: "Young-Toddler-Total"
# mention_text: "15"
# confidence: 1
# page_anchor {
#   page_refs {
#     bounding_poly {
#       normalized_vertices {
#         x: 0.791808903
#         y: 0.756923079
#       }
#       normalized_vertices {
#         x: 0.812286675
#         y: 0.756923079
#       }
#       normalized_vertices {
#         x: 0.812286675
#         y: 0.765714288
#       }
#       normalized_vertices {
#         x: 0.791808903
#         y: 0.765714288
#       }
#     }
#   }
# }
# id: "19"
# normalized_value {
#   text: "15"
# }
# ]

# %%
pd.DataFrame({ent.type_: ent.mention_text for ent in document.entities if ent.mention_text})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 pd.DataFrame({ent.type_: ent.mention_text for ent in document.entities if ent.mention_text})
#
# File D:\PyCharmProjects\ODJFS-Licensing-Reports-Webscraper\.venv\Lib\site-packages\pandas\core\frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File D:\PyCharmProjects\ODJFS-Licensing-Reports-Webscraper\.venv\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File D:\PyCharmProjects\ODJFS-Licensing-Reports-Webscraper\.venv\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File D:\PyCharmProjects\ODJFS-Licensing-Reports-Webscraper\.venv\Lib\site-packages\pandas\core\internals\construction.py:667, in _extract_index(data)
#     664         raise ValueError("Per-column arrays must each be 1-dimensional")
#     666 if not indexes and not raw_lengths:
# --> 667     raise ValueError("If using all scalar values, you must pass an index")
#     669 if have_series:
#     670     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
document.entities[1].type_
# Out:
# 'Food-Service-Risk-Level'

# %%
document.entities[1].mention_text
# Out:
# 'Level II'

# %%
document.pages[0].tables[0].header_rows[0].cells[0].layout.text_anchor
# Out:
# text_segments {
#   start_index: 1349
#   end_index: 1359
# }

# %%
print(len(document.text))
# Out:
# 9561

# %%
def table_to_dataframe(document: documentai.Document, page_index: int, table_index: int) -> pd.DataFrame:
    """
    Convert the specified table (page_index, table_index) of a Document
    into a pandas DataFrame. Attempts to use the first header row as columns.
    """
    # Safety checks
    if page_index >= len(document.pages):
        raise IndexError(f"Page index {page_index} is out of range.")
    page = document.pages[page_index]

    if table_index >= len(page.tables):
        raise IndexError(f"Table index {table_index} is out of range for page {page_index}.")
    table = page.tables[table_index]

    # Helper to extract text from a cell using text anchors
    def get_cell_text(cell: documentai.Document.Page.Table.TableCell) -> str:
        segments = cell.layout.text_anchor.text_segments
        # If multiple segments, concatenate them
        text_parts = []
        print(segments[0])
        for seg in segments:
            print(document.text[seg.start_index:seg.end_index].strip())
            print()
            text_parts.append(document.text[seg.start_index:seg.end_index])
        return "".join(text_parts).strip()

    # Extract column headers from the first header row (if it exists)
    if table.header_rows:
        header_row = table.header_rows[0]
        columns = [get_cell_text(cell) for cell in header_row.cells]
        print(columns)
    else:
        # Fallback: If no header rows, create generic column names 
        # based on the first body row (if available)
        if not table.body_rows or not table.body_rows[0].cells:
            # Empty table or no cells at all
            return pd.DataFrame()
        num_cols = len(table.body_rows[0].cells)
        columns = [f"col_{i+1}" for i in range(num_cols)]

    print("process rows")

    # Extract body rows
    rows_data = []
    for row in table.body_rows:
        row_values = [get_cell_text(cell) for cell in row.cells]
        rows_data.append(row_values)

    # Build the DataFrame
    df = pd.DataFrame(rows_data, columns=columns)
    return df


def extract_first_4_pages_tables(document: documentai.Document) -> list[pd.DataFrame]:
    """
    For each page in the first 4 pages of a Document, extract every table
    as a pandas DataFrame. Return a list of all DataFrames found.
    """
    dataframes = []
    # Only go up to 4 or the total number of pages, whichever is smaller
    max_pages = min(1, len(document.pages))

    for page_idx in range(max_pages):
        page = document.pages[page_idx]
        print(f"Processing Page {page_idx + 1}/{len(document.pages)}: found {len(page.tables)} table(s).")
        
        for table_idx, _ in enumerate(page.tables):
            df = table_to_dataframe(document, page_idx, 1)
            dataframes.append(df)
            break

    return dataframes

stop = 3
tables = extract_first_4_pages_tables(document)
tables[0]
# Out:
# Processing Page 1/5: found 5 table(s).
# start_index: 1035
# end_index: 1218
#
# Inspection Type
# Inspection Information
# Inspection Scope
# Full
# Inspection Notice
# Unannounced
# Annual
# Begin Time 2:40 PM
# End Time 5:00 PM
# Inspection Date
# 10/25/2023
# Reviewer:
# SULYN ROMER
#
# Summary of Findings
#
# ['Inspection Type\nInspection Information\nInspection Scope\nFull\nInspection Notice\nUnannounced\nAnnual\nBegin Time 2:40 PM\nEnd Time 5:00 PM\nInspection Date\n10/25/2023\nReviewer:\nSULYN ROMER\nSummary of Findings']
# process rows
# Empty DataFrame
# Columns: [Inspection Type
# Inspection Information
# Inspection Scope
# Full
# Inspection Notice
# Unannounced
# Annual
# Begin Time 2:40 PM
# End Time 5:00 PM
# Inspection Date
# 10/25/2023
# Reviewer:
# SULYN ROMER
# Summary of Findings]
# Index: []

# %%
# Out:
# Processing Page 1/5: found 5 table(s).
# Processing Page 2/5: found 1 table(s).
# Processing Page 3/5: found 0 table(s).
# Processing Page 4/5: found 0 table(s).

# %%
tables[2]
# Out:
# Empty DataFrame
# Columns: [No. Rules Verified
# No. Rules with Non-compliances No. Serious Risk
# 11
# 0
# No. Moderate Risk
# No. Low Risk
# 58
# 1
# 11]
# Index: []

# %%
pd.read_csv("data/pdf_links_final.csv")['pdf']
# Out:
# 0       https://childcaresearch.ohio.gov//pdf/00219002...
# 1       https://childcaresearch.ohio.gov//pdf/00219002...
# 2       https://childcaresearch.ohio.gov//pdf/00000030...
# 3       https://childcaresearch.ohio.gov//pdf/00219001...
# 4       https://childcaresearch.ohio.gov//pdf/00000020...
#                               ...
# 3741    https://childcaresearch.ohio.gov//pdf/00000050...
# 3742    https://childcaresearch.ohio.gov//pdf/00000020...
# 3743    https://childcaresearch.ohio.gov//pdf/00000020...
# 3744    https://childcaresearch.ohio.gov//pdf/00000020...
# 3745    https://childcaresearch.ohio.gov//pdf/00000020...
# Name: pdf, Length: 3746, dtype: object
