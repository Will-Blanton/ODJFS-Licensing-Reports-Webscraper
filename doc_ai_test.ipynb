# %%
import os
from concurrent.futures import ThreadPoolExecutor

import pandas as pd
import re

from typing import Optional

import requests
from google.api_core.client_options import ClientOptions
from google.api_core.exceptions import InternalServerError
from google.api_core.exceptions import RetryError
from google.cloud import documentai
from google.cloud import storage

from datetime import datetime
from dotenv import load_dotenv
from google.cloud import documentai
from google.cloud.documentai_toolbox import gcs_utilities

# %%
load_dotenv()
# DOC_PROCESSOR_KEY = os.getenv('DOC_PROCESSOR_KEY')
DOC_PROCESSOR_ID = os.getenv('DOC_PROCESSOR_ID')
PROJECT_ID = os.getenv('PROJECT_ID')
GCS_BUCKET = os.getenv('GCS_BUCKET')

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = os.getenv('CRED_FILE')

# %%
def create_gcs_bucket(bucket_name, delete=False):
    """Deletes the bucket if it exists, then creates a new bucket in Google Cloud Storage."""
    storage_client = storage.Client()

    # Check if the bucket already exists
    bucket = storage_client.lookup_bucket(bucket_name)
    if bucket and delete:
        print(f"Bucket {bucket_name} already exists. Deleting it.g.")
        bucket.delete(force=True)
        print(f"Bucket {bucket_name} deleted.")

        # create a new bucket
        new_bucket = storage_client.create_bucket(bucket_name)
        print(f"Bucket {new_bucket.name} created.")

    return storage_client.bucket(bucket_name)

# %%
bucket = create_gcs_bucket(GCS_BUCKET)

# %%
import numpy as np
import cv2
import fitz
import io
import tempfile
from PIL import Image


def preprocess_image(pix: fitz.Pixmap, sharpen: bool = True) -> Image.Image:
    """
    Convert a PyMuPDF pixmap to a PIL.Image that is:
      • grayscale (smaller file, consistent contrast)
      • Otsu‑binarised (keeps faint strokes, kills background noise)
      • lightly sharpened (optional) to recover thin text lines
    Returns a 3‑channel RGB image ready for PDF embedding.
    """
    # pixmap → ndarray (BGR, no alpha)
    arr = np.frombuffer(pix.samples, np.uint8)\
            .reshape(pix.height, pix.width, 4 if pix.alpha else 3)
    if pix.alpha:
        arr = cv2.cvtColor(arr, cv2.COLOR_BGRA2BGR)

    gray   = cv2.cvtColor(arr, cv2.COLOR_BGR2GRAY)

    # Otsu gives per‑page threshold; safer than “fixed 180”
    _, bin_ = cv2.threshold(gray, 0, 255,
                            cv2.THRESH_BINARY | cv2.THRESH_OTSU)

    if sharpen:
        blur  = cv2.GaussianBlur(bin_, (0, 0), 3)
        bin_  = cv2.addWeighted(bin_, 1.5, blur, -0.5, 0)

    # back to RGB so PIL→PDF works
    rgb = cv2.cvtColor(bin_, cv2.COLOR_GRAY2RGB)
    return Image.fromarray(rgb)

# %%
def download_and_upload_pdf(bucket, blob_name, pdf_url, page_count=1):
    """
    Download a PDF from a URL and upload it to GCS.
    
    :param bucket: GCS bucket object
    :param blob_name: name of the PDF file (e.g., the PDF's ID)
    :param pdf_url: URL of the PDF file
    :param page_count: number of pages to download
    
    """
    try:
        response = requests.get(pdf_url)
        response.raise_for_status()
        pdf_content = response.content

        # retrieve the first page_count pages 
        input_pdf = fitz.open(stream=pdf_content, filetype='pdf')

        images = []
        for page_num in range(min(page_count, len(input_pdf))):
            pix = input_pdf[page_num].get_pixmap(dpi=300)
            img = preprocess_image(pix, sharpen=True)
            # img = Image.frombytes("RGB", (pix.width, pix.height), pix.samples)
            # images.append(img.convert("RGB"))
            images.append(img)

        pdf_buffer = io.BytesIO()
        images[0].save(pdf_buffer, format="PDF", save_all=True, append_images=images[1:])
        pdf_buffer.seek(0)

        # output_pdf = fitz.open()
        # output_pdf.insert_pdf(input_pdf, from_page=0, to_page=page_count - 1)
        
        # convert to temporary "file" for upload 
        # pdf_buffer = io.BytesIO()
        # output_pdf.save(pdf_buffer, incremental=False)
        # pdf_buffer.seek(0)

        # upload to GCS
        blob = bucket.blob(blob_name)
        blob.upload_from_file(pdf_buffer, content_type='application/pdf')
        print(f"Uploaded {blob_name} to GCS.")
    except Exception as e:
        print(f"Failed to process {pdf_url}: {e}")

# %%
pdf_links = pd.read_csv("test/pdf_links_test.csv", index_col=0)
pdf_links.head()
# Out:
#                                                  program_name  \
# program_id
# 2190020840  "BECOMING ME" SOCIAL AND EMOTIONAL LEARNING EN...
# 2190020063                              1ST CHOICE CHILD CARE
# 300864                           1ST FRIENDS LEARNING ACADEMY
# 2190019999                                    3MB AFTERSCHOOL
# 201048                             3T LEARNING ACADEMY LLC 11
#
#                                                           pdf  \
# program_id
# 2190020840  https://childcaresearch.ohio.gov//pdf/00219002...
# 2190020063  https://childcaresearch.ohio.gov//pdf/00219002...
# 300864      https://childcaresearch.ohio.gov//pdf/00000030...
# 2190019999  https://childcaresearch.ohio.gov//pdf/00219001...
# 201048      https://childcaresearch.ohio.gov//pdf/00000020...
#
#                            Address        City    Zip
# program_id
# 2190020840           2627 PARK AVE  CINCINNATI  45206
# 2190020063      4303 CLEVELAND AVE    COLUMBUS  43224
# 300864               1930 PEARL RD   BRUNSWICK  44212
# 2190019999  18316 ST. CLAIR AVENUE   CLEVELAND  44110
# 201048           7523 READING ROAD  CINCINNATI  45237

# %%
pdf_links.iloc[10]
# Out:
# program_name                                A 2 Z PRESCHOOL, INC.
# pdf             https://childcaresearch.ohio.gov//pdf/00000010...
# Address                                        190 WOODROW AVENUE
# City                                              SAINT CLAIRSVIL
# Zip                                                         43950
# Name: 100361, dtype: object

# %%
fail_pdf = pdf_links[pdf_links.index == 200979]
fail_pdf = fail_pdf.iloc[0]["pdf"]
fail_pdf
# Out:
# 'https://childcaresearch.ohio.gov//pdf/000000200979_2024-10-02_ANNUAL.pdf'

# %%
len(pd.read_csv("data/pdf_links_final.csv",index_col=0)['pdf'])
# Out:
# 3746

# %%
from document_AI_run import upload_files_to_gcs
upload_files_to_gcs(
    bucket, 
    pd.read_csv("data/pdf_links_final.csv", index_col=0)['pdf'].iloc[1:50],
    batch_size=10,
    num_workers=5,
    num_pages=1
)
# Out:
# Uploaded input/200644.pdf to GCS.
# Uploaded input/107193.pdf to GCS.
# Uploaded input/2180016960.pdf to GCS.
# Uploaded input/2190020297.pdf to GCS.
# Uploaded input/2190020063.pdf to GCS.
# Uploaded input/2220026701.pdf to GCS.
# Uploaded input/207607.pdf to GCS.
# Uploaded input/2180017710.pdf to GCS.
# Uploaded input/300864.pdf to GCS.
# Uploaded input/107064.pdf to GCS.
# Uploaded input/300001.pdf to GCS.
# Uploaded input/400468.pdf to GCS.
# Uploaded input/2190019999.pdf to GCS.
# Uploaded input/2200022316.pdf to GCS.
# Uploaded input/2210025267.pdf to GCS.
# Uploaded input/401180.pdf to GCS.
# Uploaded input/306543.pdf to GCS.
# Uploaded input/201048.pdf to GCS.
# Uploaded input/2210024741.pdf to GCS.
# Uploaded input/2180018327.pdf to GCS.
# Uploaded input/2220026936.pdf to GCS.
# Uploaded input/2190019520.pdf to GCS.
# Uploaded input/2220025784.pdf to GCS.
# Failed to process https://childcaresearch.ohio.gov//pdf/002210025291_2025-01-09_ANNUAL.pdf: 404 Client Error: Not Found for url: https://childcaresearch.ohio.gov//pdf/002210025291_2025-01-09_ANNUAL.pdf
# Uploaded input/307578.pdf to GCS.
# Uploaded input/2210025027.pdf to GCS.
# Uploaded input/400610.pdf to GCS.
# Uploaded input/104554.pdf to GCS.
# Uploaded input/203941.pdf to GCS.
# Uploaded input/200979.pdf to GCS.
# Uploaded input/207853.pdf to GCS.
# Uploaded input/400839.pdf to GCS.
# Uploaded input/500191.pdf to GCS.
# Uploaded input/2200022786.pdf to GCS.
# Uploaded input/2170014790.pdf to GCS.
# Uploaded input/400965.pdf to GCS.
# Uploaded input/205547.pdf to GCS.
# Failed to process https://childcaresearch.ohio.gov//pdf/002180019164_2024-08-07_ANNUAL.pdf: 404 Client Error: Not Found for url: https://childcaresearch.ohio.gov//pdf/002180019164_2024-08-07_ANNUAL.pdf
# Uploaded input/500276.pdf to GCS.
# Uploaded input/407193.pdf to GCS.
# Uploaded input/2200022034.pdf to GCS.
# Uploaded input/2170012482.pdf to GCS.
# Uploaded input/100361.pdf to GCS.
# Uploaded input/307339.pdf to GCS.
# Uploaded input/2180016806.pdf to GCS.
# Uploaded input/401176.pdf to GCS.
# Uploaded input/2230027669.pdf to GCS.
# Uploaded input/2170012594.pdf to GCS.
# Uploaded input/2230027870.pdf to GCS.
# All batches processed.

# %%
test_link = pdf_links.iloc[0]['pdf']
test_link
# Out:
# 'https://childcaresearch.ohio.gov//pdf/002190020840_2023-10-25_ANNUAL.pdf'

# %%
# download_and_upload_pdf(bucket, "input/fail.pdf", fail_pdf)
# Out:
# Uploaded input/fail.pdf to GCS.

# %%
# download_and_upload_pdf(bucket, "input/002190020840.pdf", test_link)
# Out:
# Uploaded input/002190020840.pdf to GCS.

# %%
def get_fields(document):
    fields = {}
    
    for ent in document.entities:

        # process the table (listed as grouped fields/entities)
        if ent.properties:

            for ep in ent.properties:

                ep_label = ep.type_

                if ep.properties:
                    # handle two levels of nesting
                    fields.update({f"{ep_label}-{prop.type_}": prop.mention_text for prop in ep.properties}) 
                else:
                    fields[ep_label] = ep.mention_text

        else:
            fields[ent.type_] = ent.mention_text
            
    return fields

# get_fields(processed)
def process_batch(client: documentai.DocumentProcessorServiceClient, request, timeout, verbose=False):
    
    operation = client.batch_process_documents(request)
    
    # wait until the batch process is complete
    try:
        if verbose:
            print(f"Waiting for operation {operation.operation.name} to complete...")
        operation.result(timeout=timeout)
    # Catch exception when operation doesn't finish before timeout
    except (RetryError, InternalServerError) as e:
        print(e.message)
            
    # NOTE: Can also use callbacks for asynchronous processing
    #
    # def my_callback(future):
    #   result = future.result()
    #
    # operation.add_done_callback(my_callback)

    # After the operation is complete,
    # get output document information from operation metadata
    metadata = documentai.BatchProcessMetadata(operation.metadata)

    if metadata.state != documentai.BatchProcessMetadata.State.SUCCEEDED:
        raise ValueError(f"Batch Process Failed: {metadata.state_message}")

    storage_client = storage.Client()
    
    documents = []

    if verbose:
        print("Output files:")
    # One process per Input Document
    for process in list(metadata.individual_process_statuses):
        # output_gcs_destination format: gs://BUCKET/PREFIX/OPERATION_NUMBER/INPUT_FILE_NUMBER/
        # The Cloud Storage API requires the bucket name and URI prefix separately
        matches = re.match(r"gs://(.*?)/(.*)", process.output_gcs_destination)
        if not matches:
            print(
                "Could not parse output GCS destination:",
                process.output_gcs_destination,
            )
            continue

        output_bucket, output_prefix = matches.groups()

        # Get List of Document Objects from the Output Bucket
        output_blobs = storage_client.list_blobs(output_bucket, prefix=output_prefix)

        # Document AI may output multiple JSON files per source file
        current_doc_fields = {}
        doc_ID = None
        for blob in output_blobs:
            # Document AI should only output JSON files to GCS
            if blob.content_type != "application/json":
                print(
                    f"Skipping non-supported file: {blob.name} - Mimetype: {blob.content_type}"
                )
                continue
                
            if doc_ID is None:
                doc_ID = blob.name.split("/")[-1].split(".")[0].split("-")[0]

            # Download JSON File as bytes object and convert to Document Object
            if verbose:
                print(f"Fetching {blob.name}")
            document = documentai.Document.from_json(
                blob.download_as_bytes(), ignore_unknown_fields=True
            )
            
            fields = get_fields(document)
            current_doc_fields.update(fields)
            
        documents.append(pd.DataFrame(current_doc_fields, index=[doc_ID]))

    return pd.concat(documents)
from concurrent.futures import ThreadPoolExecutor, as_completed

def extract_from_pdfs(
        gcs_bucket_name: str,
        gcs_prefix: str,
        batch_size: int = 50,
        location='us',
        field_mask: Optional[str] = None,
        timeout: int = 400,
        threads: Optional[int] = None,
        verbose=True
):
    def process_doc_batch(batch):

        request = documentai.BatchProcessRequest(
            name=proc_name,
            input_documents=batch,
            document_output_config=output_config
        )

        return process_batch(client, request, timeout, verbose)

    opts = ClientOptions(api_endpoint=f"{location}-documentai.googleapis.com")

    client = documentai.DocumentProcessorServiceClient(client_options=opts)
    
    # Cloud Storage URI for the Output Directory
    gcs_output_config = documentai.DocumentOutputConfig.GcsOutputConfig(
        gcs_uri=f"gs://{GCS_BUCKET}/output/", field_mask=field_mask
    )

    # Where to write results
    output_config = documentai.DocumentOutputConfig(gcs_output_config=gcs_output_config)

    batches = gcs_utilities.create_batches(
        gcs_bucket_name=gcs_bucket_name, 
        gcs_prefix=gcs_prefix, 
        batch_size=batch_size
    )

    proc_name = client.processor_path(PROJECT_ID, location="us", processor=DOC_PROCESSOR_ID)

    if verbose:
        print(f"{len(batches)} batch(es) created.")
    
    processed_docs = [] 
    
    with ThreadPoolExecutor(max_workers=threads) as executor:   
        futures = [executor.submit(process_doc_batch, batch) for batch in batches]

        for future in as_completed(futures):
            try:
                response = future.result()
                processed_docs.append(response)
            except Exception as e:
                print(f"Batch failed: {e}")
        
    return pd.concat(processed_docs)
processed = extract_from_pdfs(
        gcs_bucket_name=GCS_BUCKET,
        gcs_prefix="test/",
        batch_size=2,
        field_mask="entities", 
        threads=1,
        timeout=900
)
processed
# Out:
# 1 batch(es) created.
# Waiting for operation projects/415387208113/locations/us/operations/15685490811490539594 to complete...
# Output files:
# Fetching output/15685490811490539594/0/100361-0.json
# Fetching output/15685490811490539594/1/201048-0.json
#        Begin-Time End-Time Fire-Inspection-Approval-Date  \
# 100361   10:20 AM  1:58 PM                    03/19/2024
# 201048   10:05 AM  4:10 PM                    08/29/2024
#
#        Food-Service-Risk-Level Inspection-Date Inspection-Notice  \
# 100361                Level II      12/10/2024       Unannounced
# 201048               Level III      10/29/2024       Unannounced
#
#        Inspection-Scope Infant-Full-Time Infant-Part-Time Infant-Total  ...  \
# 100361             Full               11                0           11  ...
# 201048             Full                4                0            4  ...
#
#        Maximum-Under-2 No-Low-Risk No-Moderate-Risk  \
# 100361              26           2                0
# 201048              22           9                2
#
#        No-Rules-with-Non-compliances No-Serious-Risk Occupancy-Limit  \
# 100361                             2               0             100
# 201048                             9               0              62
#
#                       Program-Name       Reviewer Use-Group-Code  \
# 100361       A 2 Z PRESCHOOL, INC.  JENNIFER COPE              E
# 201048  3T LEARNING ACADEMY LLC 11  ZIBUTE OSGOOD              E
#
#        Building-Approval-Date
# 100361                    NaN
# 201048             03/30/2020
#
# [2 rows x 40 columns]

# %%
pdf_links.iloc[0:2]
# Out:
#                                                  program_name  \
# program_id
# 2190020840  "BECOMING ME" SOCIAL AND EMOTIONAL LEARNING EN...
# 2190020063                              1ST CHOICE CHILD CARE
#
#                                                           pdf  \
# program_id
# 2190020840  https://childcaresearch.ohio.gov//pdf/00219002...
# 2190020063  https://childcaresearch.ohio.gov//pdf/00219002...
#
#                        Address        City    Zip
# program_id
# 2190020840       2627 PARK AVE  CINCINNATI  45206
# 2190020063  4303 CLEVELAND AVE    COLUMBUS  43224

# %%
pdf_links.index = pdf_links.index.astype(str)

# %%
pdf_links.merge(processed, how='outer', left_index=True, right_index=True)
# Out:
#                                                  program_name  \
# 100361                                  A 2 Z PRESCHOOL, INC.
# 104554                 A PLACE TO LEARN AND GROW INCORPORATED
# 107064                               A PLACE FOR EVERYONE LLC
# 107193                A BEAUTIFUL CHILD'S PRESCHOOL & DAYCARE
# 200644                            A GREAT START PRESCHOOL INC
# 200979                             A BRIGHTER START CHILDCARE
# 201048                             3T LEARNING ACADEMY LLC 11
# 203941                 A & D DAY CARE AND LEARNING CENTER INC
# 205547                                       A CHILD'S GARDEN
# 207607                               A BETTER CHILD CARE CORP
# 2170012482                  A CHILD'S JOURNEY LEARNING CENTER
# 2180018327   A PLACE TO GROW DAYCARE CENTER AND PRESCHOOL LLC
# 2180019164                        A + CHILDCARE AND PRESCHOOL
# 2190019520           A KIDS ONLY EARLY LEARNING CENTER INC. 4
# 2190019999                                    3MB AFTERSCHOOL
# 2190020063                              1ST CHOICE CHILD CARE
# 2190020297                   A MOTHERS TOUCH LAST FOREVER LLC
# 2190020840  "BECOMING ME" SOCIAL AND EMOTIONAL LEARNING EN...
# 2200022034                   A MILLION DREAMS LEARNING CENTER
# 2200022786                   A & J KIDUCATION LEARNING CENTER
# 2210025027                   A BLESSED CHILD LEARNING ACADEMY
# 2210025267                            A PLACE TO GROW ACADEMY
# 2210025291                            5 STAR LEARNING ACADEMY
# 2220025784                          4 MYKIDZ LEARNING ACADEMY
# 2220026701                           A JOYFUL JOURNEY ACADEMY
# 2220026936                               A BETTER DAY ACADEMY
# 2230027669              A MOTHER'S LUV EARLY EDUCATION CENTER
# 300001                                      A JUBILEE ACADEMY
# 300864                           1ST FRIENDS LEARNING ACADEMY
# 306543                                A KID'S PLACE CHILDCARE
# 307578                      A KIDS ONLY EARLY LEARNING CT INC
# 400468                              A BETTER CHOICE CHILDCARE
# 400839           A LITTLE PIECE OF HEAVEN LEARNING CENTER LLC
# 400965                               A LOVE FOR CHILDREN, LLC
# 401176                        A CHILD'S PLACE LEARNING CENTER
# 401180              A BETTER CHOICE DAYCARE & LEARNING CENTER
#
#                                                           pdf  \
# 100361      https://childcaresearch.ohio.gov//pdf/00000010...
# 104554      https://childcaresearch.ohio.gov//pdf/00000010...
# 107064      https://childcaresearch.ohio.gov//pdf/00000010...
# 107193      https://childcaresearch.ohio.gov//pdf/00000010...
# 200644      https://childcaresearch.ohio.gov//pdf/00000020...
# 200979      https://childcaresearch.ohio.gov//pdf/00000020...
# 201048      https://childcaresearch.ohio.gov//pdf/00000020...
# 203941      https://childcaresearch.ohio.gov//pdf/00000020...
# 205547      https://childcaresearch.ohio.gov//pdf/00000020...
# 207607      https://childcaresearch.ohio.gov//pdf/00000020...
# 2170012482  https://childcaresearch.ohio.gov//pdf/00217001...
# 2180018327  https://childcaresearch.ohio.gov//pdf/00218001...
# 2180019164  https://childcaresearch.ohio.gov//pdf/00218001...
# 2190019520  https://childcaresearch.ohio.gov//pdf/00219001...
# 2190019999  https://childcaresearch.ohio.gov//pdf/00219001...
# 2190020063  https://childcaresearch.ohio.gov//pdf/00219002...
# 2190020297  https://childcaresearch.ohio.gov//pdf/00219002...
# 2190020840  https://childcaresearch.ohio.gov//pdf/00219002...
# 2200022034  https://childcaresearch.ohio.gov//pdf/00220002...
# 2200022786  https://childcaresearch.ohio.gov//pdf/00220002...
# 2210025027  https://childcaresearch.ohio.gov//pdf/00221002...
# 2210025267  https://childcaresearch.ohio.gov//pdf/00221002...
# 2210025291  https://childcaresearch.ohio.gov//pdf/00221002...
# 2220025784  https://childcaresearch.ohio.gov//pdf/00222002...
# 2220026701  https://childcaresearch.ohio.gov//pdf/00222002...
# 2220026936  https://childcaresearch.ohio.gov//pdf/00222002...
# 2230027669  https://childcaresearch.ohio.gov//pdf/00223002...
# 300001      https://childcaresearch.ohio.gov//pdf/00000030...
# 300864      https://childcaresearch.ohio.gov//pdf/00000030...
# 306543      https://childcaresearch.ohio.gov//pdf/00000030...
# 307578      https://childcaresearch.ohio.gov//pdf/00000030...
# 400468      https://childcaresearch.ohio.gov//pdf/00000040...
# 400839      https://childcaresearch.ohio.gov//pdf/00000040...
# 400965      https://childcaresearch.ohio.gov//pdf/00000040...
# 401176      https://childcaresearch.ohio.gov//pdf/00000040...
# 401180      https://childcaresearch.ohio.gov//pdf/00000040...
#
#                                 Address               City    Zip Begin-Time  \
# 100361               190 WOODROW AVENUE    SAINT CLAIRSVIL  43950   10:20 AM
# 104554                  407 SIXTH ST NW             CANTON  44702        NaN
# 107064                   5192 DARROW RD             HUDSON  44236        NaN
# 107193                 1449 BRITTAIN RD              AKRON  44310        NaN
# 200644               7001 FAR HILLS AVE             DAYTON  45459        NaN
# 200979               2765 BLUE ROCK RD.         CINCINNATI  45239        NaN
# 201048                7523 READING ROAD         CINCINNATI  45237   10:05 AM
# 203941                1049 INFIRMARY RD             DAYTON  45418        NaN
# 205547                5427 JULMAR DRIVE         CINCINNATI  45238        NaN
# 207607             6945 HARRISON AVENUE         CINCINNATI  45247        NaN
# 2170012482           846 S. YEARLING RD          WHITEHALL  43213        NaN
# 2180018327        115 W ST CLAIR ST # A              EATON  45320        NaN
# 2180019164                3310 WALES RD          MASSILLON  44646        NaN
# 2190019520        2505 SOUTH RIDGE EAST          ASHTABULA  44004        NaN
# 2190019999       18316 ST. CLAIR AVENUE          CLEVELAND  44110        NaN
# 2190020063           4303 CLEVELAND AVE           COLUMBUS  43224        NaN
# 2190020297        3006/3010 DOUGLAS RD.             TOLEDO  43606        NaN
# 2190020840                2627 PARK AVE         CINCINNATI  45206        NaN
# 2200022034              541 MAIN STREET            MILFORD  45150        NaN
# 2200022786         1736 COMMERCE STREET         WELLSVILLE  43968        NaN
# 2210025027       3870 E. LIVINGSTON AVE           COLUMBUS  43227        NaN
# 2210025267          6760 DISCOVERY BLVD             DUBLIN  43017        NaN
# 2210025291               8264 CLARA AVE         CINCINNATI  45239        NaN
# 2220025784            10461 PIPPIN ROAD         CINCINNATI  45231        NaN
# 2220026701            1536 BARNETT ROAD           COLUMBUS  43227        NaN
# 2220026936             3128 MAYFIELD RD  CLEVELAND HEIGHTS  44118        NaN
# 2230027669              3142 READING RD         CINCINNATI  45229        NaN
# 300001             15751 LAKESHORE BLVD          CLEVELAND  44110        NaN
# 300864                    1930 PEARL RD          BRUNSWICK  44212        NaN
# 306543                  30121 LORAIN RD      NORTH OLMSTED  44070        NaN
# 307578                  2621 STATE ROAD          ASHTABULA  44004        NaN
# 400468                   2572 CLEVELAND           COLUMBUS  43211        NaN
# 400839              771 HARRISBURG PIKE           COLUMBUS  43223        NaN
# 400965                 4656 HEATON ROAD           COLUMBUS  43229        NaN
# 401176            2010 OFFICEVIEW PLACE       REYNOLDSBURG  43068        NaN
# 401180      2960 E. DUBLIN GRANVILLE RD           COLUMBUS  43231        NaN
#
#            End-Time Fire-Inspection-Approval-Date Food-Service-Risk-Level  \
# 100361      1:58 PM                    03/19/2024                Level II
# 104554          NaN                           NaN                     NaN
# 107064          NaN                           NaN                     NaN
# 107193          NaN                           NaN                     NaN
# 200644          NaN                           NaN                     NaN
# 200979          NaN                           NaN                     NaN
# 201048      4:10 PM                    08/29/2024               Level III
# 203941          NaN                           NaN                     NaN
# 205547          NaN                           NaN                     NaN
# 207607          NaN                           NaN                     NaN
# 2170012482      NaN                           NaN                     NaN
# 2180018327      NaN                           NaN                     NaN
# 2180019164      NaN                           NaN                     NaN
# 2190019520      NaN                           NaN                     NaN
# 2190019999      NaN                           NaN                     NaN
# 2190020063      NaN                           NaN                     NaN
# 2190020297      NaN                           NaN                     NaN
# 2190020840      NaN                           NaN                     NaN
# 2200022034      NaN                           NaN                     NaN
# 2200022786      NaN                           NaN                     NaN
# 2210025027      NaN                           NaN                     NaN
# 2210025267      NaN                           NaN                     NaN
# 2210025291      NaN                           NaN                     NaN
# 2220025784      NaN                           NaN                     NaN
# 2220026701      NaN                           NaN                     NaN
# 2220026936      NaN                           NaN                     NaN
# 2230027669      NaN                           NaN                     NaN
# 300001          NaN                           NaN                     NaN
# 300864          NaN                           NaN                     NaN
# 306543          NaN                           NaN                     NaN
# 307578          NaN                           NaN                     NaN
# 400468          NaN                           NaN                     NaN
# 400839          NaN                           NaN                     NaN
# 400965          NaN                           NaN                     NaN
# 401176          NaN                           NaN                     NaN
# 401180          NaN                           NaN                     NaN
#
#            Inspection-Date  ... Maximum-Under-2 No-Low-Risk No-Moderate-Risk  \
# 100361          12/10/2024  ...              26           2                0
# 104554                 NaN  ...             NaN         NaN              NaN
# 107064                 NaN  ...             NaN         NaN              NaN
# 107193                 NaN  ...             NaN         NaN              NaN
# 200644                 NaN  ...             NaN         NaN              NaN
# 200979                 NaN  ...             NaN         NaN              NaN
# 201048          10/29/2024  ...              22           9                2
# 203941                 NaN  ...             NaN         NaN              NaN
# 205547                 NaN  ...             NaN         NaN              NaN
# 207607                 NaN  ...             NaN         NaN              NaN
# 2170012482             NaN  ...             NaN         NaN              NaN
# 2180018327             NaN  ...             NaN         NaN              NaN
# 2180019164             NaN  ...             NaN         NaN              NaN
# 2190019520             NaN  ...             NaN         NaN              NaN
# 2190019999             NaN  ...             NaN         NaN              NaN
# 2190020063             NaN  ...             NaN         NaN              NaN
# 2190020297             NaN  ...             NaN         NaN              NaN
# 2190020840             NaN  ...             NaN         NaN              NaN
# 2200022034             NaN  ...             NaN         NaN              NaN
# 2200022786             NaN  ...             NaN         NaN              NaN
# 2210025027             NaN  ...             NaN         NaN              NaN
# 2210025267             NaN  ...             NaN         NaN              NaN
# 2210025291             NaN  ...             NaN         NaN              NaN
# 2220025784             NaN  ...             NaN         NaN              NaN
# 2220026701             NaN  ...             NaN         NaN              NaN
# 2220026936             NaN  ...             NaN         NaN              NaN
# 2230027669             NaN  ...             NaN         NaN              NaN
# 300001                 NaN  ...             NaN         NaN              NaN
# 300864                 NaN  ...             NaN         NaN              NaN
# 306543                 NaN  ...             NaN         NaN              NaN
# 307578                 NaN  ...             NaN         NaN              NaN
# 400468                 NaN  ...             NaN         NaN              NaN
# 400839                 NaN  ...             NaN         NaN              NaN
# 400965                 NaN  ...             NaN         NaN              NaN
# 401176                 NaN  ...             NaN         NaN              NaN
# 401180                 NaN  ...             NaN         NaN              NaN
#
#            No-Rules-with-Non-compliances No-Serious-Risk Occupancy-Limit  \
# 100361                                 2               0             100
# 104554                               NaN             NaN             NaN
# 107064                               NaN             NaN             NaN
# 107193                               NaN             NaN             NaN
# 200644                               NaN             NaN             NaN
# 200979                               NaN             NaN             NaN
# 201048                                 9               0              62
# 203941                               NaN             NaN             NaN
# 205547                               NaN             NaN             NaN
# 207607                               NaN             NaN             NaN
# 2170012482                           NaN             NaN             NaN
# 2180018327                           NaN             NaN             NaN
# 2180019164                           NaN             NaN             NaN
# 2190019520                           NaN             NaN             NaN
# 2190019999                           NaN             NaN             NaN
# 2190020063                           NaN             NaN             NaN
# 2190020297                           NaN             NaN             NaN
# 2190020840                           NaN             NaN             NaN
# 2200022034                           NaN             NaN             NaN
# 2200022786                           NaN             NaN             NaN
# 2210025027                           NaN             NaN             NaN
# 2210025267                           NaN             NaN             NaN
# 2210025291                           NaN             NaN             NaN
# 2220025784                           NaN             NaN             NaN
# 2220026701                           NaN             NaN             NaN
# 2220026936                           NaN             NaN             NaN
# 2230027669                           NaN             NaN             NaN
# 300001                               NaN             NaN             NaN
# 300864                               NaN             NaN             NaN
# 306543                               NaN             NaN             NaN
# 307578                               NaN             NaN             NaN
# 400468                               NaN             NaN             NaN
# 400839                               NaN             NaN             NaN
# 400965                               NaN             NaN             NaN
# 401176                               NaN             NaN             NaN
# 401180                               NaN             NaN             NaN
#
#                           Program-Name       Reviewer Use-Group-Code  \
# 100361           A 2 Z PRESCHOOL, INC.  JENNIFER COPE              E
# 104554                             NaN            NaN            NaN
# 107064                             NaN            NaN            NaN
# 107193                             NaN            NaN            NaN
# 200644                             NaN            NaN            NaN
# 200979                             NaN            NaN            NaN
# 201048      3T LEARNING ACADEMY LLC 11  ZIBUTE OSGOOD              E
# 203941                             NaN            NaN            NaN
# 205547                             NaN            NaN            NaN
# 207607                             NaN            NaN            NaN
# 2170012482                         NaN            NaN            NaN
# 2180018327                         NaN            NaN            NaN
# 2180019164                         NaN            NaN            NaN
# 2190019520                         NaN            NaN            NaN
# 2190019999                         NaN            NaN            NaN
# 2190020063                         NaN            NaN            NaN
# 2190020297                         NaN            NaN            NaN
# 2190020840                         NaN            NaN            NaN
# 2200022034                         NaN            NaN            NaN
# 2200022786                         NaN            NaN            NaN
# 2210025027                         NaN            NaN            NaN
# 2210025267                         NaN            NaN            NaN
# 2210025291                         NaN            NaN            NaN
# 2220025784                         NaN            NaN            NaN
# 2220026701                         NaN            NaN            NaN
# 2220026936                         NaN            NaN            NaN
# 2230027669                         NaN            NaN            NaN
# 300001                             NaN            NaN            NaN
# 300864                             NaN            NaN            NaN
# 306543                             NaN            NaN            NaN
# 307578                             NaN            NaN            NaN
# 400468                             NaN            NaN            NaN
# 400839                             NaN            NaN            NaN
# 400965                             NaN            NaN            NaN
# 401176                             NaN            NaN            NaN
# 401180                             NaN            NaN            NaN
#
#            Building-Approval-Date
# 100361                        NaN
# 104554                        NaN
# 107064                        NaN
# 107193                        NaN
# 200644                        NaN
# 200979                        NaN
# 201048                 03/30/2020
# 203941                        NaN
# 205547                        NaN
# 207607                        NaN
# 2170012482                    NaN
# 2180018327                    NaN
# 2180019164                    NaN
# 2190019520                    NaN
# 2190019999                    NaN
# 2190020063                    NaN
# 2190020297                    NaN
# 2190020840                    NaN
# 2200022034                    NaN
# 2200022786                    NaN
# 2210025027                    NaN
# 2210025267                    NaN
# 2210025291                    NaN
# 2220025784                    NaN
# 2220026701                    NaN
# 2220026936                    NaN
# 2230027669                    NaN
# 300001                        NaN
# 300864                        NaN
# 306543                        NaN
# 307578                        NaN
# 400468                        NaN
# 400839                        NaN
# 400965                        NaN
# 401176                        NaN
# 401180                        NaN
#
# [36 rows x 45 columns]
